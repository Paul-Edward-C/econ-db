# %%
import pandas as pd
import numpy as np
from fuzzywuzzy import fuzz

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def get_similarity(s1, s2):    
    vectorizer = TfidfVectorizer()
    vectors = vectorizer.fit_transform([s1, s2])
    similarity = cosine_similarity(vectors[0], vectors[1])
    
    return similarity[0][0]

# %%
mapping_path = "db/mapping/export/export_mapping.csv"
data_path = "db/tw/data/export/tw_export_m.csv"

mapping = pd.read_csv(mapping_path, index_col=None)
data = pd.read_csv(data_path, index_col=[0])

# %%
index = 0
keep_list = [1, 5, 3]
mapping_list = mapping.iloc[[index]].T[index]

if mapping_list[2] == "Value":
    mapping_list = mapping_list[[1, 5, 3]].dropna()
else:
    mapping_list = mapping_list[[1, 5, 2, 3]].dropna()
    
if "Total" in mapping_list:
    mapping_list.remove("Total")
    
mapping_string = ", ".join(mapping_list)
mapping_string
# Out:
# 'Exports, USD'

# %%
fuzzscore_list = []
cosscore_list = []


data_columns = data.columns

for i in mapping_list:
    data_columns = data_columns[data_columns.str.lower().str.contains(i.lower())]

data_columns_revised = data_columns.str.replace(", All", "")
    
for i in data_columns_revised:
    fuzzscore = fuzz.token_sort_ratio(i, mapping_string) / 100
    cosscore = get_similarity(i, mapping_string)
    
    fuzzscore_list.append(fuzzscore)
    cosscore_list.append(cosscore)

# %%
result = pd.DataFrame({"dataname": data_columns.tolist(), "fuzzscore": fuzzscore_list, "cosscore": cosscore_list}).sort_values(by=["cosscore", "fuzzscore"], ascending=False)
result = result.loc[result['fuzzscore'] > 0.6]
result['overallscore'] = (result['fuzzscore'] + result['cosscore']) / 2
result['mappingname'] = mapping_string
result['mappingindex'] = index
result['matchinglength'] = len(result)

result.index = range(len(all_result), len(all_result) + len(result))

# %%
from tqdm import tqdm
all_result = pd.DataFrame()

for index in tqdm(mapping.index, desc='Processing mapping', unit='mapping'):
    mapping_list = mapping.iloc[[index]].T[index]
    if mapping_list[0] != "Monthly":
        continue

    if mapping_list[2] == "Value":
        mapping_list = mapping_list[[1, 5, 3]].dropna()
    else:
        mapping_list = mapping_list[[1, 5, 2, 3]].dropna()

    if "Total" in mapping_list:
        mapping_list.remove("Total")

    mapping_string = ", ".join(mapping_list)

    data_columns = data.columns

    for i in mapping_list:
        data_columns = data_columns[data_columns.str.lower().str.contains(i.lower())]
    

    data_columns_revised = data_columns.str.replace(", All", "")

    fuzzscore_list = []
    cosscore_list = []
    for i in data_columns_revised:
        fuzzscore = fuzz.token_sort_ratio(i, mapping_string) / 100
        cosscore = get_similarity(i, mapping_string)

        fuzzscore_list.append(fuzzscore)
        cosscore_list.append(cosscore)

    result = pd.DataFrame({"dataname": data_columns.tolist(), "fuzzscore": fuzzscore_list, "cosscore": cosscore_list}).sort_values(by=["cosscore", "fuzzscore"], ascending=False)
    result = result.loc[(result['fuzzscore'] > 0.6) & (result['cosscore'] > 0.5)]
        
    result['overallscore'] = (result['fuzzscore'] + result['cosscore']) / 2
    result['mappingname'] = mapping_string
    result['mappingindex'] = index
    result['matchinglength'] = len(result)

    result.index = range(len(all_result), len(all_result) + len(result))

    all_result = pd.concat([all_result, result], axis=0)
# Out:
# Processing mapping: 100%|█████████████| 5346/5346 [00:11<00:00, 474.18mapping/s]

# %%
duplicated_dataname_u = all_result[all_result['dataname'].duplicated()]['dataname'].unique()

for duplicate in duplicated_dataname_u:
    duplicate_df = all_result.loc[all_result['dataname'] == duplicate].sort_values(by="overallscore", ascending=False)
    all_result.drop(duplicate_df.index[1:], inplace=True)

# %%
duplicated_mappingname_u = all_result[all_result['mappingname'].duplicated()]['mappingname'].unique()

for duplicate in duplicated_mappingname_u:
    duplicate_df = all_result.loc[all_result['mappingname'] == duplicate].sort_values(by="overallscore", ascending=False)
    all_result.drop(duplicate_df.index[1:], inplace=True)

# %%
all_result
# Out:
#                                            dataname  fuzzscore  cosscore  \
# 0                                 Exports, All, USD       1.00  1.000000
# 31              Exports, Semiconductors HS 776, USD       0.88  0.656973
# 36                Exports, China and Hong Kong, USD       0.71  0.579739
# 39                      Exports, DM excl Japan, USD       0.81  0.656973
# 44                                 Exports, EU, USD       1.00  1.000000
# 50                                 Exports, US, USD       1.00  1.000000
# 62                                Exports, All, LCU       1.00  1.000000
# 92              Exports, Semiconductors HS 776, LCU       0.88  0.656973
# 97                Exports, China and Hong Kong, LCU       0.71  0.579739
# 100                     Exports, DM excl Japan, LCU       0.81  0.656973
# 105                                Exports, EU, LCU       1.00  1.000000
# 111                                Exports, US, LCU       1.00  1.000000
# 117                        Exports, All, USD, % YoY       1.00  1.000000
# 133      Exports, Semiconductors HS 776, USD, % YoY       0.90  0.709297
# 135        Exports, China and Hong Kong, USD, % YoY       0.75  0.634809
# 137              Exports, DM excl Japan, USD, % YoY       0.84  0.709297
# 139                         Exports, EU, USD, % YoY       1.00  1.000000
# 141                         Exports, US, USD, % YoY       1.00  1.000000
# 154                        Exports, All, LCU, % YoY       1.00  1.000000
# 170      Exports, Semiconductors HS 776, LCU, % YoY       0.90  0.709297
# 172        Exports, China and Hong Kong, LCU, % YoY       0.75  0.634809
# 174              Exports, DM excl Japan, LCU, % YoY       0.84  0.709297
# 176                         Exports, EU, LCU, % YoY       1.00  1.000000
# 178                         Exports, US, LCU, % YoY       1.00  1.000000
# 180                           Exports, All, USD, SA       1.00  1.000000
# 191         Exports, Semiconductors HS 776, USD, SA       0.89  0.709297
# 193           Exports, China and Hong Kong, USD, SA       0.74  0.634809
# 194                 Exports, DM excl Japan, USD, SA       0.83  0.709297
# 196                            Exports, EU, USD, SA       1.00  1.000000
# 199                            Exports, US, USD, SA       1.00  1.000000
# 209                           Exports, All, LCU, SA       1.00  1.000000
# 231         Exports, Semiconductors HS 776, LCU, SA       0.89  0.709297
# 235           Exports, China and Hong Kong, LCU, SA       0.74  0.634809
# 238                 Exports, DM excl Japan, LCU, SA       0.83  0.709297
# 242                            Exports, EU, LCU, SA       1.00  1.000000
# 247                            Exports, US, LCU, SA       1.00  1.000000
# 282                    Exports, All, USD, % MoM, SA       1.00  1.000000
# 303  Exports, Semiconductors HS 776, USD, % MoM, SA       0.90  0.747407
# 305    Exports, China and Hong Kong, USD, % MoM, SA       0.77  0.676479
# 307          Exports, DM excl Japan, USD, % MoM, SA       0.86  0.747407
# 309                     Exports, EU, USD, % MoM, SA       1.00  1.000000
# 311                     Exports, US, USD, % MoM, SA       1.00  1.000000
# 329                               Imports, All, USD       1.00  1.000000
# 344                               Imports, All, LCU       1.00  1.000000
# 355                        Imports, All, USD, % YoY       1.00  1.000000
# 367                        Imports, All, LCU, % YoY       1.00  1.000000
# 374                           Imports, All, USD, SA       1.00  1.000000
# 381                           Imports, All, LCU, SA       1.00  1.000000
# 398                    Imports, All, USD, % MoM, SA       1.00  1.000000
# 414                              Trade balance, USD       1.00  1.000000
# 420                              Trade balance, LCU       1.00  1.000000
# 422                          Trade balance, USD, SA       1.00  1.000000
# 426                          Trade balance, LCU, SA       1.00  1.000000
#
#      overallscore                              mappingname  mappingindex  \
# 0        1.000000                             Exports, USD             0
# 31       0.768486             Exports, Semiconductors, USD             1
# 36       0.644869                      Exports, China, USD             5
# 39       0.733486                      Exports, Japan, USD             6
# 44       1.000000                         Exports, EU, USD             9
# 50       1.000000                         Exports, US, USD            10
# 62       1.000000                             Exports, LCU            11
# 92       0.768486             Exports, Semiconductors, LCU            12
# 97       0.644869                      Exports, China, LCU            16
# 100      0.733486                      Exports, Japan, LCU            17
# 105      1.000000                         Exports, EU, LCU            20
# 111      1.000000                         Exports, US, LCU            21
# 117      1.000000                      Exports, USD, % YoY            33
# 133      0.804649      Exports, Semiconductors, USD, % YoY            34
# 135      0.692404               Exports, China, USD, % YoY            38
# 137      0.774649               Exports, Japan, USD, % YoY            39
# 139      1.000000                  Exports, EU, USD, % YoY            42
# 141      1.000000                  Exports, US, USD, % YoY            43
# 154      1.000000                      Exports, LCU, % YoY            44
# 170      0.804649      Exports, Semiconductors, LCU, % YoY            45
# 172      0.692404               Exports, China, LCU, % YoY            49
# 174      0.774649               Exports, Japan, LCU, % YoY            50
# 176      1.000000                  Exports, EU, LCU, % YoY            53
# 178      1.000000                  Exports, US, LCU, % YoY            54
# 180      1.000000                         Exports, USD, SA            66
# 191      0.799649         Exports, Semiconductors, USD, SA            67
# 193      0.687404                  Exports, China, USD, SA            71
# 194      0.769649                  Exports, Japan, USD, SA            72
# 196      1.000000                     Exports, EU, USD, SA            75
# 199      1.000000                     Exports, US, USD, SA            76
# 209      1.000000                         Exports, LCU, SA            77
# 231      0.799649         Exports, Semiconductors, LCU, SA            78
# 235      0.687404                  Exports, China, LCU, SA            82
# 238      0.769649                  Exports, Japan, LCU, SA            83
# 242      1.000000                     Exports, EU, LCU, SA            86
# 247      1.000000                     Exports, US, LCU, SA            87
# 282      1.000000                  Exports, USD, % MoM, SA           165
# 303      0.823704  Exports, Semiconductors, USD, % MoM, SA           166
# 305      0.723240           Exports, China, USD, % MoM, SA           170
# 307      0.803704           Exports, Japan, USD, % MoM, SA           171
# 309      1.000000              Exports, EU, USD, % MoM, SA           174
# 311      1.000000              Exports, US, USD, % MoM, SA           175
# 329      1.000000                             Imports, USD           594
# 344      1.000000                             Imports, LCU           605
# 355      1.000000                      Imports, USD, % YoY           627
# 367      1.000000                      Imports, LCU, % YoY           638
# 374      1.000000                         Imports, USD, SA           660
# 381      1.000000                         Imports, LCU, SA           671
# 398      1.000000                  Imports, USD, % MoM, SA           759
# 414      1.000000                       Trade balance, USD          1188
# 420      1.000000                       Trade balance, LCU          1199
# 422      1.000000                   Trade balance, USD, SA          1254
# 426      1.000000                   Trade balance, LCU, SA          1265
#
#      matchinglength
# 0                31
# 31                5
# 36                3
# 39                5
# 44                6
# 50               12
# 62               30
# 92                5
# 97                3
# 100               5
# 105               6
# 111               6
# 117              16
# 133               2
# 135               2
# 137               2
# 139               2
# 141              13
# 154              16
# 170               2
# 172               2
# 174               2
# 176               2
# 178               2
# 180              11
# 191               2
# 193               1
# 194               2
# 196               3
# 199              10
# 209              22
# 231               4
# 235               3
# 238               4
# 242               5
# 247               5
# 282              21
# 303               2
# 305               2
# 307               2
# 309               2
# 311              18
# 329              11
# 344              11
# 355               7
# 367               7
# 374               4
# 381               9
# 398               8
# 414               3
# 420               2
# 422               2
# 426               1

# %%
mapping.loc[all_result['mappingindex'], "TW"] = all_result['dataname'].tolist()

# %%
mapping.loc[~mapping["TW"].isna()]
# Out:
#             0              1      2               3           4  \
# 0     Monthly        Exports  Value             USD       Total
# 1     Monthly        Exports  Value             USD  By Product
# 5     Monthly        Exports  Value             USD  By Country
# 6     Monthly        Exports  Value             USD  By Country
# 9     Monthly        Exports  Value             USD  By Country
# 10    Monthly        Exports  Value             USD  By Country
# 11    Monthly        Exports  Value             LCU       Total
# 12    Monthly        Exports  Value             LCU  By Product
# 16    Monthly        Exports  Value             LCU  By Country
# 17    Monthly        Exports  Value             LCU  By Country
# 20    Monthly        Exports  Value             LCU  By Country
# 21    Monthly        Exports  Value             LCU  By Country
# 33    Monthly        Exports  Value      USD, % YoY       Total
# 34    Monthly        Exports  Value      USD, % YoY  By Product
# 38    Monthly        Exports  Value      USD, % YoY  By Country
# 39    Monthly        Exports  Value      USD, % YoY  By Country
# 42    Monthly        Exports  Value      USD, % YoY  By Country
# 43    Monthly        Exports  Value      USD, % YoY  By Country
# 44    Monthly        Exports  Value      LCU, % YoY       Total
# 45    Monthly        Exports  Value      LCU, % YoY  By Product
# 49    Monthly        Exports  Value      LCU, % YoY  By Country
# 50    Monthly        Exports  Value      LCU, % YoY  By Country
# 53    Monthly        Exports  Value      LCU, % YoY  By Country
# 54    Monthly        Exports  Value      LCU, % YoY  By Country
# 66    Monthly        Exports  Value         USD, SA       Total
# 67    Monthly        Exports  Value         USD, SA  By Product
# 71    Monthly        Exports  Value         USD, SA  By Country
# 72    Monthly        Exports  Value         USD, SA  By Country
# 75    Monthly        Exports  Value         USD, SA  By Country
# 76    Monthly        Exports  Value         USD, SA  By Country
# 77    Monthly        Exports  Value         LCU, SA       Total
# 78    Monthly        Exports  Value         LCU, SA  By Product
# 82    Monthly        Exports  Value         LCU, SA  By Country
# 83    Monthly        Exports  Value         LCU, SA  By Country
# 86    Monthly        Exports  Value         LCU, SA  By Country
# 87    Monthly        Exports  Value         LCU, SA  By Country
# 165   Monthly        Exports  Value  USD, % MoM, SA       Total
# 166   Monthly        Exports  Value  USD, % MoM, SA  By Product
# 170   Monthly        Exports  Value  USD, % MoM, SA  By Country
# 171   Monthly        Exports  Value  USD, % MoM, SA  By Country
# 174   Monthly        Exports  Value  USD, % MoM, SA  By Country
# 175   Monthly        Exports  Value  USD, % MoM, SA  By Country
# 594   Monthly        Imports  Value             USD       Total
# 605   Monthly        Imports  Value             LCU       Total
# 627   Monthly        Imports  Value      USD, % YoY       Total
# 637   Monthly        Imports  Value      USD, % YoY  By Country
# 638   Monthly        Imports  Value      LCU, % YoY       Total
# 660   Monthly        Imports  Value         USD, SA       Total
# 670   Monthly        Imports  Value         USD, SA  By Country
# 671   Monthly        Imports  Value         LCU, SA       Total
# 759   Monthly        Imports  Value  USD, % MoM, SA       Total
# 769   Monthly        Imports  Value  USD, % MoM, SA  By Country
# 1188  Monthly  Trade balance  Value             USD       Total
# 1199  Monthly  Trade balance  Value             LCU       Total
# 1254  Monthly  Trade balance  Value         USD, SA       Total
# 1265  Monthly  Trade balance  Value         LCU, SA       Total
#
#                    5                                                 TW
# 0                NaN                                  Exports, All, USD
# 1     Semiconductors                Exports, Semiconductors HS 776, USD
# 5              China                  Exports, China and Hong Kong, USD
# 6              Japan                        Exports, DM excl Japan, USD
# 9                 EU                                   Exports, EU, USD
# 10                US                                   Exports, US, USD
# 11               NaN                                  Exports, All, LCU
# 12    Semiconductors                Exports, Semiconductors HS 776, LCU
# 16             China                  Exports, China and Hong Kong, LCU
# 17             Japan                        Exports, DM excl Japan, LCU
# 20                EU                                   Exports, EU, LCU
# 21                US                                   Exports, US, LCU
# 33               NaN                           Exports, All, USD, % YoY
# 34    Semiconductors         Exports, Semiconductors HS 776, USD, % YoY
# 38             China           Exports, China and Hong Kong, USD, % YoY
# 39             Japan                 Exports, DM excl Japan, USD, % YoY
# 42                EU                            Exports, EU, USD, % YoY
# 43                US                            Exports, US, USD, % YoY
# 44               NaN                           Exports, All, LCU, % YoY
# 45    Semiconductors         Exports, Semiconductors HS 776, LCU, % YoY
# 49             China           Exports, China and Hong Kong, LCU, % YoY
# 50             Japan                 Exports, DM excl Japan, LCU, % YoY
# 53                EU                            Exports, EU, LCU, % YoY
# 54                US                            Exports, US, LCU, % YoY
# 66               NaN                              Exports, All, USD, SA
# 67    Semiconductors            Exports, Semiconductors HS 776, USD, SA
# 71             China              Exports, China and Hong Kong, USD, SA
# 72             Japan                    Exports, DM excl Japan, USD, SA
# 75                EU                               Exports, EU, USD, SA
# 76                US                               Exports, US, USD, SA
# 77               NaN                              Exports, All, LCU, SA
# 78    Semiconductors            Exports, Semiconductors HS 776, LCU, SA
# 82             China              Exports, China and Hong Kong, LCU, SA
# 83             Japan                    Exports, DM excl Japan, LCU, SA
# 86                EU                               Exports, EU, LCU, SA
# 87                US                               Exports, US, LCU, SA
# 165              NaN                       Exports, All, USD, % MoM, SA
# 166   Semiconductors     Exports, Semiconductors HS 776, USD, % MoM, SA
# 170            China       Exports, China and Hong Kong, USD, % MoM, SA
# 171            Japan             Exports, DM excl Japan, USD, % MoM, SA
# 174               EU                        Exports, EU, USD, % MoM, SA
# 175               US                        Exports, US, USD, % MoM, SA
# 594              NaN                                  Imports, All, USD
# 605              NaN                                  Imports, All, LCU
# 627              NaN                           Imports, All, USD, % YoY
# 637               US          Imports, Capital goods, parts, USD, % YoY
# 638              NaN                           Imports, All, LCU, % YoY
# 660              NaN                              Imports, All, USD, SA
# 670               US               Imports, Semi mfg equipment, USD, SA
# 671              NaN                              Imports, All, LCU, SA
# 759              NaN                       Imports, All, USD, % MoM, SA
# 769               US  Imports, Semi mfg equipment, USD, % MoM, SA, 3mma
# 1188             NaN                                 Trade balance, USD
# 1199             NaN                                 Trade balance, LCU
# 1254             NaN                             Trade balance, USD, SA
# 1265             NaN                             Trade balance, LCU, SA

# %%
len(all_result)
# Out:
# 53

# %%
import datetime

# Create a datetime object
dt = datetime.datetime(2023, 5, 18, 12, 0, 0)

# Convert datetime to epoch time
epoch_time = dt.timestamp()

print(epoch_time)
# Out:
# 1684382400.0
